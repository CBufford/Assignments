# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Christian Bufford**
# I am currently a Geophysical Systems Instructor

# %% [markdown]
# *I am interested in data science because I want to improve my orginizations efficiency by reducing the amount of data that we do not analyze and putting that data to good use.*

# %% [markdown]
# ### The code below will simply add 345 with 678

# %%
345+678
# Out:
# 1023

# %% [markdown]
# ~~Make a Simple Bulleted List with a strikethrough~~
# - Apple
# - Grape
# - Pear
# - Orange
#
#
#
# >Make a Simple Numbered List with a blocked quote
# 1. Apple
# 2. Grape
# 3. Pear
# 4. Orange
#
#
#
#
#
#
#
#
# |Things I know how to do|Things I dont know how to do|
# |-------|------|
# |Make lists with fruits| Quantum Mechanics|
# |Spell Apple|Intersteller Travel|
# |Make this table|Desgin a Nuclear Reactor|
